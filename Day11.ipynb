# %% [markdown]
# <a href="https://colab.research.google.com/github/ichhitsapkota143/Machine-Learning/blob/main/Day11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Why Seaborn?**
#   1. provides a layer of abstraction hence simpler to use
#   2. better aesthetics
#   3. more graphs included

# %% [markdown]
# # **Relational Plot**
#
#
# *   to see the statistical relation betweeen 2 or more variables
# *   Bivariate analysis \\
# Plots under this section:
#   1. scatterplot
#   2. lineplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#scatter plot
#it is a axes level function(usually rectangular shape)
sns.scatterplot(tips,x='total_bill',y='tip')
#scatterplot(nameOfData,x=plotOnX-axis,y=plotOnY-axis)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#scatterplot in figure level (usually square shaped)
#relplot()
sns.relplot(tips,x='total_bill',y='tip',kind='scatter',hue='sex',style='time',size='size')

# %%
#it is recommended to use figure level figure than axes level, because we can use figure level figure to obtain different axes plot

# %%
#hue in scatter
#it is used to plot different category of a variable using different graph
sns.scatterplot(tips,x='total_bill',y='tip',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#style is also used to represent different category of a variable using dots, cross
sns.scatterplot(tips,x='total_bill',y='tip',hue='sex',style='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#size is used to set size of the figure elements, depending upon the numbers
sns.scatterplot(tips,x='total_bill',y='tip',hue='sex',style='time',size='size')
#here 'size' is the entry in the dataset
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#line plot
#similar to scatter plot, but continuous, usually used for entry against time
sns.lineplot(tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
gap=px.data.gapminder()
temp_df=gap[gap['country']=='Nepal']
temp_df
#importing data from pyplot library
# Out:
#      country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 1068   Nepal      Asia  1952   36.157   9182536   545.865723       NPL
# 1069   Nepal      Asia  1957   37.686   9682338   597.936356       NPL
# 1070   Nepal      Asia  1962   39.393  10332057   652.396859       NPL
# 1071   Nepal      Asia  1967   41.472  11261690   676.442225       NPL
# 1072   Nepal      Asia  1972   43.971  12412593   674.788130       NPL
# 1073   Nepal      Asia  1977   46.748  13933198   694.112440       NPL
# 1074   Nepal      Asia  1982   49.594  15796314   718.373095       NPL
# 1075   Nepal      Asia  1987   52.537  17917180   775.632450       NPL
# 1076   Nepal      Asia  1992   55.727  20326209   897.740360       NPL
# 1077   Nepal      Asia  1997   59.426  23001113  1010.892138       NPL
# 1078   Nepal      Asia  2002   61.340  25873917  1057.206311       NPL
# 1079   Nepal      Asia  2007   63.785  28901790  1091.359778       NPL
#
#       iso_num
# 1068      524
# ...

# %%
#axes level function
sns.lineplot(temp_df,x='year',y='lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
#figure level function
sns.relplot(temp_df,x='year',y='lifeExp',kind='line')

# %%
#hue and style
tempor_df=gap[gap['country'].isin(['India','Pakistan','Nepal'])]
tempor_df
# Out:
#        country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696      India      Asia  1952   37.373   372000000   546.565749       IND
# 697      India      Asia  1957   40.249   409000000   590.061996       IND
# 698      India      Asia  1962   43.605   454000000   658.347151       IND
# 699      India      Asia  1967   47.193   506000000   700.770611       IND
# 700      India      Asia  1972   50.651   567000000   724.032527       IND
# 701      India      Asia  1977   54.208   634000000   813.337323       IND
# 702      India      Asia  1982   56.596   708000000   855.723538       IND
# 703      India      Asia  1987   58.553   788000000   976.512676       IND
# 704      India      Asia  1992   60.223   872000000  1164.406809       IND
# 705      India      Asia  1997   61.765   959000000  1458.817442       IND
# 706      India      Asia  2002   62.879  1034172547  1746.769454       IND
# ...

# %%
sns.relplot(tempor_df,x='year',y='lifeExp',kind='line',hue='country')

# %%
sns.lineplot(tempor_df,x='year',y='lifeExp',hue='country')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
#the other difference between figure level and axes level is the ledgend, in figure level it is outside the graph and in axes level it is inside the graph

# %%
#hue and style
tempor_df=gap[gap['country'].isin(['Nepal','Brazil','Germany'])]
tempor_df
# Out:
#       country continent  year  lifeExp        pop     gdpPercap iso_alpha  \
# 168    Brazil  Americas  1952   50.917   56602560   2108.944355       BRA
# 169    Brazil  Americas  1957   53.285   65551171   2487.365989       BRA
# 170    Brazil  Americas  1962   55.665   76039390   3336.585802       BRA
# 171    Brazil  Americas  1967   57.632   88049823   3429.864357       BRA
# 172    Brazil  Americas  1972   59.504  100840058   4985.711467       BRA
# 173    Brazil  Americas  1977   61.489  114313951   6660.118654       BRA
# 174    Brazil  Americas  1982   63.336  128962939   7030.835878       BRA
# 175    Brazil  Americas  1987   65.205  142938076   7807.095818       BRA
# 176    Brazil  Americas  1992   67.057  155975974   6950.283021       BRA
# 177    Brazil  Americas  1997   69.388  168546719   7957.980824       BRA
# 178    Brazil  Americas  2002   71.006  179914212   8131.212843       BRA
# 179    Brazil  Americas  2007   72.390  190010647   9065.800825       BRA
# ...

# %%
sns.relplot(tempor_df,x='year',y='lifeExp',kind='line',hue='country',style='continent',size='iso_num')

# %%
#facet plot
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(tips,x='total_bill',y='tip',kind='scatter',hue='sex')

# %%
#facet plot is used to plot different plots of different category
#here col is used to plot male and female seperately
sns.relplot(tips,x='total_bill',y='tip',kind='scatter',col='sex',hue='sex') #plot column wise

# %%
sns.relplot(tips,x='total_bill',y='tip',kind='scatter',row='sex',hue='sex')#plot row wise, vertically

# %%
sns.relplot(tips,x='total_bill',y='tip',kind='scatter',col='sex',row='smoker',hue='sex')
#here we are plotting 4 graphs, of smoker and sex

# %%
#facet plot will only work for figure level function, not with scatter and line plot

# %%
sns.scatterplot(tips,x='total_bill',y='tip',col='sex',row='smoker',hue='sex')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-ed61e5062302> in <cell line: 0>()
# ----> 1 sns.scatterplot(tips,x='total_bill',y='tip',col='sex',row='smoker',hue='sex')
#
# /usr/local/lib/python3.11/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     634     kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
#     635
# --> 636     p.plot(ax, kwargs)
#     637
#     638     return ax
#
# /usr/local/lib/python3.11/dist-packages/seaborn/relational.py in plot(self, ax, kws)
#     436
#     437         # Draw the scatter plot
# --> 438         points = ax.scatter(x=x, y=y, **kws)
#     439
#     440         # Apply the mapping from semantic variables to artist attributes
#
# ...

# %%
#col wrap
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
sns.relplot(gap,x='lifeExp',y='gdpPercap',kind='scatter')

# %%
#to generate scatter plot for different year
sns.relplot(gap,x='lifeExp',y='gdpPercap',kind='scatter',col='year',col_wrap=3)

# %% [markdown]
# # **Distribution Plot**
#
#
# *   used for univariate analysis
# *   used to find out the distribution
# *   Range of the observation
# *   Central Tendency

# %% [markdown]
# #figure level function
# * displot
# #axes level function
# * histplot
# *kdeplot
# *rugplot

# %%
#plotting univariate histogram
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#axes level
sns.histplot(tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
#figure level
sns.displot(tips,x='total_bill',kind='hist')

# %%
#bins parameter
sns.displot(tips,x='total_bill',kind='hist',bins=20)
#dividing into 20 size

# %%
sns.displot(tips,x='total_bill',kind='hist',bins=5)

# %%
#It is also possible to visualize the distribution of categorical variables using the logic of histogram
#Discrete bins are automatically set for categorical variables
sns.displot(tips,x='day',kind='hist')
#count plot

# %%
#hue parameter
sns.displot(tips,x='tip',kind='hist',hue='sex')

# %%
#element
sns.displot(tips,x='tip',kind='hist',hue='sex',element='step')

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.displot(titanic,x='age',kind='hist',element='step',hue='sex')

# %%
#faceting using col and row
sns.displot(tips,x='tip',kind='hist',hue='sex',col='sex')
#this will not work on axes level function

# %%
#kdeplot
#Kernel Density Estimation (KDE)
#rather than using discrete bins, a kde plot smooths the observation with a Gaussian kernel, producing a continuos density element
sns.kdeplot(tips,x='total_bill')
#gives the density of probability
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# function level
sns.displot(tips,x='total_bill',kind='kde')

# %%
#hue parameter
sns.displot(tips,x='total_bill',kind='kde',hue='sex')

# %%
#fill parameter
sns.displot(tips,x='total_bill',kind='kde',hue='sex',fill=True)

# %%
#Rugplot
#plots marginal distribution by drawing ticks along the x and y axis
#this function is intended to complement other plots by showing the location of individual obeservation is an unbtrusive way

# %%
sns.kdeplot(tips,x='total_bill')
sns.rugplot(tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>
